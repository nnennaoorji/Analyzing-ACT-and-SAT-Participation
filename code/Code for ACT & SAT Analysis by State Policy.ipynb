# %% [markdown]
# # Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Hypothetical Scenario: Following recent debates on the use of the SAT and ACT tests in determining college readiness, the South Carolina State Board of Education is re-assessing its policy stance on the issue. Currently, the State does not require its highschoolers to sit for either the SAT or the ACT, but provides funding to enable 11th graders take either test for free. The State has hired me as a consultant to profer an answer to the question:
# #### Will making the SAT or ACT mandatory have any effect on the State's average test scores?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are popular standardized tests that several colleges and universities in the United States use to assess a student's college readiness and aptitude. As at 2020, more than half of the United States' 50 states required high school seniors to have taken either the SAT or the ACT as a prerequisite for graduation. However, this statistic is evolving with recent evidence that shows that standardized tests such as the SAT or ACT may favour privileged segments of the population, at the expense of minority and less privileged students. Supporters of standardized tests, however, argue that it remains the one objective parameters that places all college applicants on a level playing field, thus allowing all student populations a fair chance at compteting for college admissions. Importantly, both tests are fundamentally similar in terms of aim/objective and difficulty level. As such, a student who does well on the ACT should fare just as well on the SAT and vice versa.
#
# State policy on standardized tests vary from state to state. Some states require the SATs, while some others require the ACTs, In some states students must take either of the exam, whereas in others, neither of the tests is required. More so, in some "test optional" states, one or both of the tests are provided to interested students for free. As at 2020, 9 states required the SAT, 14 states required the ACT, and 3 states- Ohio, Idaho and Tennessee required students to take either the ACT or the SAT. Washington D.C and South Carolina are examples of states where neither test is mandatory, but provided for free to interested students.

# %% [markdown]
# ### Data
#
# In addressing the problem statement, this study analysed ACT and SAT data for the 50 states in the United States, spanning the period 2017 to 2019. The ACT dataset utilized includes information on states' participation rates and composite (average) ACT scores, while the SAT dataset contains information on state's participation rates and average scores, including a breakdown of scores by section i.e. Maths and Evidence-Based Reading and Writing (EBRW). These datasets are referenced and linked below:
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Effort has gone into researching the link between states' participation rate and average performance in both the SAT and ACT. These studies largely suggest a negative relationship between the two variables, wherein average performance by a state in a test tends to drop, as participation increases. This has been explained by the tendency for participation in a given test to increase when a test is made mandatory and/or provided for free by the state. A mandatory test also often implies that the test/test resources will be free and/or subsidized, leading to a larger and more diverse pool of candidates. In contrast, a low participation rate often implies that the candidate pool is less diverse, and usually more academically sound. This is because students who take the non-mandatory test (especially in addition to mandatory tests) tend to be "high acheivers", not indigent, and/or have access to more opportunities (Dargan, 2020).
#
# Studies have also shown a negative correlation between the SAT and the ACT, whereby a student who takes the SAT is not likely to take the ACT. Both exams have also been shown to be quite similar in terms of aim/objective, difficulty level and overall structure. In order words, it makes sense to just take one of these exams, except a student is an over-acheiver and/or is applying to multiple schools which require/accept one or both.
#
# Importantly, states tend to deploy significant amount of resources aimed at making the test more accessible and aiding students to be successful, especially in contexts where the test is mandatory. While we understand the relationship between participation and succeess rate, it will be interesting to analyse success rate by distinguishing between states where the SAT is required, states where the ACT is required, states which require at least one of the tests, and states where neither test is required. The aim is to ascertain whether relavant information can be obtained on the link between participation and student success, while controlling for a significant factor which affects participation (state policy).

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_mean (num_list):
    mean= sum(num_list)/len(num_list)
    return mean
#testing function:
x= [1,2,3,4,5]
find_mean(x)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_std_dev(num_list):
    avg= find_mean(num_list)
    for i in num_list:
        std_dev= (sum([((i-avg)**2) for i in num_list])/len(num_list))**0.5
    return std_dev

#testing code...
find_std_dev(x)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def convert_string (num):
    list_num = num.split("%")
    return float(list_num[0])/100
#testing code..
convert_string("50%")
# Out:
# 0.5

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code to import csv file into notebook:
sat_2017= pd.read_csv("../data/sat_2017.csv")
sat_2018 = pd.read_csv("../data/sat_2018.csv")
sat_2019= pd.read_csv("../data/sat_2019.csv")
act_2017= pd.read_csv("../data/act_2017.csv")
act_2018 = pd.read_csv("../data/act_2018.csv")
act_2019= pd.read_csv("../data/act_2019.csv")

# %%
#calling pandas .head() function to view first 5 lines of the data frame
sat_2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
#calling pandas .head() function to view first 5 lines of the dataframe
sat_2018.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#calling pandas .head() function to view first 5 lines of the dataframe
sat_2019.head(5)
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#calling pandas .head() function to view first 5 lines of the dataframe
act_2017.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#calling pandas .head() function to view first 5 lines of the dataframe
act_2018.head(5)
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#calling pandas .head() function to view first 5 lines of the dataframe
act_2019.head(5)
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#Checking for fundamental information about the dataframe..
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#Checking for fundamental information about the dataframe..
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#Checking for fundamental information about the dataframe..
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# Across the 3 SAT data frames, there are no null values. However, the variable "participation" which should be either and integer or a float variable retured the data type format ("Dtype") "object" i.e. string. Furthermore, the "Participation" column in the SAT_2019 dataframe contains the character "—". There is therefore need for data cleaning to facilitate analysis.

# %%
#first to fix specific issue with sat_2019 dataframe, I defined the following function:
def clean_score (p_rate):
    if p_rate == "—":
        return "0%"
    else:
        
        return p_rate

# %%
#mapping the function to series...
sat_2019['Participation Rate']= sat_2019['Participation Rate'].map(clean_score)

# %%
#success
sat_2019[sat_2019["Participation Rate"]== "0%"]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                 0%   483   462    944
# 47  Virgin Islands                 0%   490   445    935

# %%
#To convert series erroneously stored as string to integer variable, I defined the following fucntion:
def to_integer (p_rate):
    p_score= p_rate.split("%")
    return int(p_score[0])

# %%
#mapping the function to series...
sat_2017['Participation']= sat_2017['Participation'].map (to_integer)
sat_2018['Participation']= sat_2018['Participation'].map (to_integer)
sat_2019['Participation Rate']= sat_2019['Participation Rate'].map (to_integer)

# %%
#success
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     int64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
#To harmonise column names across SAT dataframes, I defined the following dictionary:
sat_column_names= {"State":"state",
                   "Participation":"participation_rate(%)",
                   "Evidence-Based Reading and Writing": "reading&writing",
                   "Math":"math",
                   "Total":"total_score"
                  }

# %%
#success
sat_2017.rename(columns=sat_column_names, inplace= True)
sat_2018.rename(columns=sat_column_names, inplace= True)
sat_2018.head()
# Out:
#         state  participation_rate(%)  reading&writing  math  total_score
# 0     Alabama                      6              595   571         1166
# 1      Alaska                     43              562   544         1106
# 2     Arizona                     29              577   572         1149
# 3    Arkansas                      5              592   576         1169
# 4  California                     60              540   536         1076

# %%
#applying same to 2019 data...
sat_column_names2= {"State":"state",
                   "Participation Rate":"participation_rate(%)",
                   "EBRW": "reading&writing",
                   "Math":"math",
                   "Total":"total_score"
                  }
sat_2019.rename(columns=sat_column_names2, inplace=True)
sat_2019.head()
# Out:
#         state  participation_rate(%)  reading&writing  math  total_score
# 0     Alabama                      7              583   560         1143
# 1      Alaska                     41              556   541         1097
# 2     Arizona                     31              569   565         1134
# 3    Arkansas                      6              582   559         1141
# 4  California                     63              534   531         1065

# %% [markdown]
# To begin my analysis, I created a column "test_policy" by defining a function which sorts through the data to classify states by applicable test policy i.e. is SAT or ACT or neither required?. Data which informed this classification was sourced from:
# * https://blog.collegevine.com/states-that-require-sat/![image.png](attachment:image.png)
# * https://reports.collegeboard.org/archive/sat-suite-program-results/2019/benefits-sat-school-day
# *https://testive.com/state-sat-act/

# %%
#Thus, we have the following function:
def sat_policy (row):
    if row == "Colorado":
        return "SAT_required"
    if row == "Delaware":
        return "SAT_required"
    if row=="Connecticut":
        return "SAT_required"
    if row=="Illinois":
        return "SAT_required"
    if row== "Maine":
        return "SAT_required"
    if row== "Michigan":
        return "SAT_required"
    if row=="New Hampshire":
        return "SAT_required"
    if row=="Rhode Island":
        return "SAT_required"
    if row=="West Virginia":
        return "SAT_required"
    elif row== "Hawaii":
        return "ACT_required"
    elif row== "Kentucky":
        return "ACT_required"
    elif row== "Nebraska":
        return "ACT_required"
    elif row== "Montana":
        return "ACT_required"
    elif row== "North Carolina":
        return "ACT_required"
    elif row=="Nevada":
        return "ACT_required"
    elif row== "Wisconsin":
        return "ACT_required"
    elif row== "Wyoming":
        return "ACT_required"
    elif row=="Alabama":
        return "ACT_required"
    elif row== "Louisiana":
        return "ACT_required"
    elif row==" Mississippi":
        return "ACT_required"
    elif row== "Missouri":
        return "ACT_required"
    elif row== "North Dakota":
        return "ACT_required"
    elif row== "Utah":
        return "ACT_required"
    elif row== "Ohio":
        return "ACT or SAT"
    elif row== "Idaho":
        return "ACT or SAT"
    elif row== "Tennessee":
        return "ACT or SAT"
    else:
        return "neither_required"

# %%
#applying the function to the dataframe, and storing to a new column "test_policy"
sat_2017["test_policy"]= sat_2017.apply(lambda row: sat_policy(row['state']),axis=1)
sat_2018["test_policy"]= sat_2018.apply(lambda row: sat_policy(row['state']),axis=1)
sat_2019["test_policy"]= sat_2019.apply(lambda row: sat_policy(row['state']),axis=1)

# %%
#success
sat_2017.head()
# Out:
#         state  participation_rate(%)  reading&writing  math  total_score  \
# 0     Alabama                      5              593   572         1165
# 1      Alaska                     38              547   533         1080
# 2     Arizona                     30              563   553         1116
# 3    Arkansas                      3              614   594         1208
# 4  California                     53              531   524         1055
#
#         test_policy
# 0      ACT_required
# 1  neither_required
# 2  neither_required
# 3  neither_required
# 4  neither_required

# %%
#success
sat_2018.head()
# Out:
#         state  participation_rate(%)  reading&writing  math  total_score  \
# 0     Alabama                      6              595   571         1166
# 1      Alaska                     43              562   544         1106
# 2     Arizona                     29              577   572         1149
# 3    Arkansas                      5              592   576         1169
# 4  California                     60              540   536         1076
#
#         test_policy
# 0      ACT_required
# 1  neither_required
# 2  neither_required
# 3  neither_required
# 4  neither_required

# %%
#success
sat_2019.head()
# Out:
#         state  participation_rate(%)  reading&writing  math  total_score  \
# 0     Alabama                      7              583   560         1143
# 1      Alaska                     41              556   541         1097
# 2     Arizona                     31              569   565         1134
# 3    Arkansas                      6              582   559         1141
# 4  California                     63              534   531         1065
#
#         test_policy
# 0      ACT_required
# 1  neither_required
# 2  neither_required
# 3  neither_required
# 4  neither_required

# %% [markdown]
# I then applied the same steps on the ACT dataframes:

# %%
#Checking for fundamental information about the dataframe..
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
#Checking for fundamental information about the dataframe..
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
#Checking for fundamental information about the dataframe..
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Across the 3 ACT data frames, there are no null values. However, the series "participation" which should be either and integer or a float variable retured the data type format ("Dtype") "object" i.e. string. Also, in the act_2017 dataframe, the series "Composite" was erroneously stored as a string variable, rather than integer or float. There is therefore need to convert the series to their appropriate format.

# %%
#mapping the earlier defined "to_integer" function to the series...
act_2017['Participation']= act_2017['Participation'].map (to_integer)
act_2018['Participation']= act_2018['Participation'].map (to_integer)
act_2019['Participation']= act_2019['Participation'].map (to_integer)

# %%
#success
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   Composite      52 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
#success
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.0+ KB

# %%
#success
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   Composite      52 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# The act_2017 data frame contains additional data on scores for each section of the test. To harmonise the dataframe with that of 2018 and 2019, I "dropped" these extra columns.

# %%
#Thus:
act_2017.drop(columns=["English", "Math", "Science", "Reading"], inplace= True)

# %%
#success
act_2017.head()
# Out:
#       State  Participation Composite
# 0  National             60      21.0
# 1   Alabama            100      19.2
# 2    Alaska             65      19.8
# 3   Arizona             62      19.7
# 4  Arkansas            100      19.4

# %%
#Renaming columns:
act_column_names= {"State":"state",
                   "Participation":"participation_rate(%)",
                   "Composite":"total_score"
                  }
act_2017.rename(columns=act_column_names, inplace= True)
act_2018.rename(columns=act_column_names, inplace= True)
act_2019.rename(columns=act_column_names, inplace= True)
act_2019.head()
# Out:
#         state  participation_rate(%)  total_score
# 0     Alabama                    100         18.9
# 1      Alaska                     38         20.1
# 2     Arizona                     73         19.0
# 3    Arkansas                    100         19.3
# 4  California                     23         22.6

# %%
#As was done above, I defined a function to classify states by test policy.
def act_policy (row):
    if row== "Hawaii":
        return "ACT_required"
    if row== "Kentucky":
        return "ACT_required"
    if row== "Nebraska":
        return "ACT_required"
    if row== "Montana":
        return "ACT_required"
    if row== "North Carolina":
        return "ACT_required"
    if row=="Nevada":
        return "ACT_required"
    if row== "Wisconsin":
        return "ACT_required"
    if row== "Wyoming":
        return "ACT_required"
    if row=="Alabama":
        return "ACT_required"
    if row== "Louisiana":
        return "ACT_required"
    if row==" Mississippi":
        return "ACT_required"
    if row== "Missouri":
        return "ACT_required"
    if row== "North Dakota":
        return "ACT_required"
    if row== "Utah":
        return "ACT_required"
    elif row == "Colorado":
        return "SAT_required"
    elif row == "Delaware":
        return "SAT_required"
    elif row=="Connecticut":
        return "SAT_required"
    elif row=="Illinois":
        return "SAT_required"
    elif row== "Maine":
        return "SAT_required"
    elif row== "Michigan":
        return "SAT_required"
    elif row=="New Hampshire":
        return "SAT_required"
    elif row=="Rhode Island":
        return "SAT_required"
    elif row=="West Virginia":
        return "SAT_required"
    elif row== "Ohio":
        return "ACT or SAT"
    elif row== "Idaho":
        return "ACT or SAT"
    elif row== "Tennessee":
        return "ACT or SAT"
    else:
        return "neither_required"

# %%
#applying the function to the dataframe and storing information into a new column "test_policy"...
act_2017["test_policy"]= act_2017.apply(lambda row: act_policy(row['state']),axis=1)
act_2018["test_policy"]= act_2018.apply(lambda row: act_policy(row['state']),axis=1)
act_2019["test_policy"]= act_2019.apply(lambda row: act_policy(row['state']),axis=1)
act_2019.head()
# Out:
#         state  participation_rate(%)  total_score       test_policy
# 0     Alabama                    100         18.9      ACT_required
# 1      Alaska                     38         20.1  neither_required
# 2     Arizona                     73         19.0  neither_required
# 3    Arkansas                    100         19.3  neither_required
# 4  California                     23         22.6  neither_required

# %%
#In trying to compute descriptive statistics on this dataframe, I noticed an issue with the data, not yet addressed.
#The total_score variable in act_2017 was erronously stores as a string variable.
act_2017.tail()
# Out:
#             state  participation_rate(%) total_score       test_policy
# 47       Virginia                     29        23.8  neither_required
# 48     Washington                     29        21.9  neither_required
# 49  West Virginia                     69        20.4      SAT_required
# 50      Wisconsin                    100        20.5      ACT_required
# 51        Wyoming                    100       20.2x      ACT_required

# %%
#To clean:
act_2017.at[51,'total_score']='20'

# %%
act_2017.tail()
# Out:
#             state  participation_rate(%) total_score       test_policy
# 47       Virginia                     29        23.8  neither_required
# 48     Washington                     29        21.9  neither_required
# 49  West Virginia                     69        20.4      SAT_required
# 50      Wisconsin                    100        20.5      ACT_required
# 51        Wyoming                    100          20      ACT_required

# %%
#converting series to float ...
def to_float(score):
    return float(score)
act_2017['total_score']=act_2017['total_score'].map(to_float)

# %%
#success
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  52 non-null     object
#  1   participation_rate(%)  52 non-null     int64
#  2   total_score            52 non-null     float64
#  3   test_policy            52 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.8+ KB

# %% [markdown]
# Upon preliminary exploratory analysis of the data frames, I have made the decision to merge the dataframes into 1 dataframe on the basis of the "state" column. To facilitate this, I will be renaming each dataframe column uniquely as follows:

# %%
sat_2017= sat_2017.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"sat_p_rate_2017",
                   "reading&writing": "sat_r&w_2017",
                   "math":"sat_math_2017",
                   "total_score":"sat_total_2017",
                   "test_policy":"sat_2017_policy"})

# %%
sat_2018= sat_2018.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"sat_p_rate_2018",
                   "reading&writing": "sat_r&w_2018",
                   "math":"sat_math_2018",
                   "total_score":"sat_total_2018",
                   "test_policy":"sat_2018_policy"})

# %%
sat_2019= sat_2019.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"sat_p_rate_2019",
                   "reading&writing": "sat_r&w_2019",
                   "math":"sat_math_2019",
                   "total_score":"sat_total_2019",
                   "test_policy":"sat_2019_policy"})

# %%
#dropping the national average row from act_2017 dataframe:
act_2017= act_2017.drop(act_2017[act_2017['state']== "National"]. index[0])

# %%
act_2017= act_2017.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"act_p_rate_2017",
                   "total_score":"act_total_2017",
                   "test_policy":"act_2017_policy"})

# %%
act_2018= act_2018.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"act_p_rate_2018",
                   "total_score":"act_total_2018",
                   "test_policy":"act_2018_policy"})

# %%
act_2019= act_2019.rename(index=str, columns={"state":"state",
                   "participation_rate(%)":"act_p_rate_2019",
                   "total_score":"act_total_2019",
                   "test_policy":"act_2019_policy"})

# %%
#merging 2017 ACT and SAT data frames using the state in each data frame as key
tests_2017= pd.merge(sat_2017, act_2017, how = "outer", on ='state')

# %%
#Maine was duplicated, hence we drop:
act_2018= act_2018.drop(act_2018[act_2018['state']== "Maine"].index[0])

# %%
#Harmonising "District of Columbia" between 2018 test data to facilitate merging:
act_2018.at[act_2018[act_2018['state']=="District of columbia"].index[0], "state"]= "District of Columbia"

# %%
#merging 2018 tests
tests_2018= pd.merge(sat_2018, act_2018, how = "outer", on ='state')

# %%
#need to drop national from act 2019 dataframe
act_2019=act_2019.drop(act_2019[act_2019['state']== "National"].index[0])

# %%
#need to drop puerto rico & Virgin Islands from sat_2019 dataframe 
sat_2019= sat_2019.drop(sat_2019[sat_2019['state']== "Puerto Rico"].index[0])
sat_2019= sat_2019.drop(sat_2019[sat_2019['state']== "Virgin Islands"].index[0])

# %%
#merging 2019 datasets
tests_2019= pd.merge(sat_2019, act_2019, how = "outer", on ='state')

# %%
#finally, combining all three...
df1= pd.merge(tests_2017, tests_2018, on = 'state')

# %%
sat_act_df= pd.merge(df1, tests_2019, on = 'state')

# %%
#Saving the data to a CSV file...
#final_filename = os.path.join(rel_datapath, "final.csv")
sat_act_df.to_csv("final_sat_act_data.csv")

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ### Data Dictionary
#
# |Feature | Dataset | Type | Description|
# |---|---|---|---|
# |state| ACT&SAT | object|State in the USA|
# |sat_p_rate_2017| SAT_2017 | integer | State SAT Participation Rate 2017 |
# |sat_r&w_2017| SAT 2017 | integer | Average Score in SAT reading & writing section |
# |sat_math_2017| SAT 2017 | integer | Average Score in SAT Math section |
# |sat_total_2017| SAT 2017 | integer | Average Total Score |
# |sat_2017_policy | SAT 2017 | object | State Policy on SAT |
# |sat_p_rate_2018| SAT 2018 | integer | State SAT Participation Rate in 2018 |
# |sat_r&w_2018| SAT 2018 | integer | Average Score in SAT reading & writing section |
# |sat_math_2018| SAT 2018 | integer | Average Score in SAT Math section |
# |sat_total_2018| SAT 2018 | integer  | Average Total Score |
# |sat_2018_policy | SAT 2018 | object | State Policy on SAT |
# |sat_p_rate_2019| SAT 2019 | integer | State SAT Participation Rate in 2019 |
# |sat_r&w_2019| SAT 2019 | integer | Average Score in SAT reading & writing section |
# |sat_math_2019| SAT 2019 | integer | Average Score in SAT Math section |
# |sat_total_2019| SAT 2019 | integer | Average Total Score |
# |sat_2019_policy | SAT 2019 | object | State Policy on SAT |
# |act_p_rate_2017 | ACT 2017 | integer | State ACT Participation Rate in 2017 |
# |act_total_2017 | ACT 2017 | float | Average Total Score |
# |act_2017_policy | ACT 2017 | object | State Policy on ACT |
# |act_p_rate_2018 | ACT 2018 | integer | State ACT Participation Rate in 2017 |
# |act_total_2018 | ACT 2018 | float | Average Total Score |
# |act_2018_policy | ACT 2018 | object | State Policy on ACT |
# |act_p_rate_2019 | ACT 2019 | integer | State ACT Participation Rate in 2017 |
# |act_total_2019 | ACT 2019 | float | Average Total Score |
# |act_2019_policy | ACT 2019 | object | State Policy on ACT |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#First, some summary statistics:
sat_act_df.describe()
# Out:
#        sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# count        51.000000     51.000000      51.000000       51.000000
# mean         39.803922    569.117647     547.627451     1126.098039
# std          35.276632     45.666901      84.909119       92.494812
# min           2.000000    482.000000      52.000000      950.000000
# 25%           4.000000    533.500000     522.000000     1055.500000
# 50%          38.000000    559.000000     548.000000     1107.000000
# 75%          66.000000    613.000000     599.000000     1212.000000
# max         100.000000    644.000000     651.000000     1295.000000
#
#        act_p_rate_2017  act_total_2017  sat_p_rate_2018  sat_r&w_2018  \
# count        51.000000       51.000000        51.000000     51.000000
# mean         65.254902       21.515686        45.745098    563.686275
# std          32.140842        2.023499        37.314256     47.502627
# min           8.000000       17.800000         2.000000    480.000000
# ...

# %% [markdown]
# From the table above we can see that:
# * SAT participation grew by 11.2 percentage points in the review period, while ACT participation fell by 6.6 percentage points.
# * Nationwide total average score on the SATs declined year-on-year in the review period.
# * Nationwide total average score on the ACTs interestingly remained constant (approx 21.5) in each year from 2017-2019
# * Standard deviation was high across all indicators showing high variability of indicators nationwide.

# %%
#code inspired by https://github.com/sgodfrey66
sd = {i: round(find_std_dev(sat_act_df[i]),2) for i in sat_act_df.columns if sat_act_df[i].dtypes != object}
sd
# Out:
# {'sat_p_rate_2017': 34.93,
#  'sat_r&w_2017': 45.22,
#  'sat_math_2017': 84.07,
#  'sat_total_2017': 91.58,
#  'act_p_rate_2017': 31.82,
#  'act_total_2017': 2.0,
#  'sat_p_rate_2018': 36.95,
#  'sat_r&w_2018': 47.03,
#  'sat_math_2018': 47.3,
#  'sat_total_2018': 93.23,
#  'act_p_rate_2018': 33.7,
#  'act_total_2018': 2.09,
#  'sat_p_rate_2019': 38.37,
#  'sat_r&w_2019': 45.79,
#  'sat_math_2019': 50.79,
#  'sat_total_2019': 96.24,
#  'act_p_rate_2019': 34.18,
#  'act_total_2019': 2.17}

# %%
#Which states have the highest participation rates for the 2017 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2017'], ascending= False).head(5)
# Out:
#                    state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 8   District of Columbia              100           482            468
# 22              Michigan              100           509            495
# 6            Connecticut              100           530            512
# 7               Delaware              100           503            492
# 29         New Hampshire               96           532            520
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 8              950  neither_required               32            24.2
# 22            1005      SAT_required               29            24.1
# 6             1041      SAT_required               31            25.2
# 7              996      SAT_required               18            24.1
# 29            1052      SAT_required               18            25.5
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
#Which states have the highest participation rates for the 2018 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2018'], ascending= False).head(5)
# Out:
#           state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 5      Colorado               11           606            595            1201
# 6   Connecticut              100           530            512            1041
# 7      Delaware              100           503            492             996
# 22     Michigan              100           509            495            1005
# 12        Idaho               93           513            493            1005
#
#    sat_2017_policy  act_p_rate_2017  act_total_2017 act_2017_policy  \
# 5     SAT_required              100            20.8    SAT_required
# 6     SAT_required               31            25.2    SAT_required
# 7     SAT_required               18            24.1    SAT_required
# 22    SAT_required               29            24.1    SAT_required
# 12      ACT or SAT               38            22.3      ACT or SAT
#
#     sat_p_rate_2018  ...  act_total_2018  act_2018_policy  sat_p_rate_2019  \
# ...

# %%
#Which states have the highest participation rates for the 2019 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2019'], ascending= False).head(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 39  Rhode Island               71           539            524
# 13      Illinois                9           559            556
# 22      Michigan              100           509            495
# 5       Colorado               11           606            595
# 6    Connecticut              100           530            512
#
#     sat_total_2017 sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 39            1062    SAT_required               21            24.0
# 13            1115    SAT_required               93            21.4
# 22            1005    SAT_required               29            24.1
# 5             1201    SAT_required              100            20.8
# 6             1041    SAT_required               31            25.2
#
#    act_2017_policy  sat_p_rate_2018  ...  act_total_2018  act_2018_policy  \
# 39    SAT_required               97  ...            24.2     SAT_required
# ...

# %%
#Which states have the lowest participation rates for the 2017 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2017'], ascending= False).tail(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 3       Arkansas                3           614            594
# 50       Wyoming                3           626            604
# 34  North Dakota                2           635            621
# 24   Mississippi                2           634            607
# 15          Iowa                2           641            635
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 3             1208  neither_required              100            19.4
# 50            1230      ACT_required              100            20.0
# 34            1256      ACT_required               98            20.3
# 24            1242  neither_required              100            18.6
# 15            1275  neither_required               67            21.9
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 3   neither_required                5  ...            19.4  neither_required
# ...

# %%
#Which states have the lowest participation rates for the 2018 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2018'], ascending= False).tail(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 24   Mississippi                2           634            607
# 15          Iowa                2           641            635
# 49     Wisconsin                3           642            649
# 50       Wyoming                3           626            604
# 34  North Dakota                2           635            621
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 24            1242  neither_required              100            18.6
# 15            1275  neither_required               67            21.9
# 49            1291      ACT_required              100            20.5
# 50            1230      ACT_required              100            20.0
# 34            1256      ACT_required               98            20.3
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 24  neither_required                3  ...            18.6  neither_required
# ...

# %%
#Which states have the lowest participation rates for the 2019 SAT?
sat_act_df.sort_values(by=['sat_p_rate_2019'], ascending= False).tail(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 24   Mississippi                2           634            607
# 15          Iowa                2           641            635
# 49     Wisconsin                3           642            649
# 50       Wyoming                3           626            604
# 34  North Dakota                2           635            621
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 24            1242  neither_required              100            18.6
# 15            1275  neither_required               67            21.9
# 49            1291      ACT_required              100            20.5
# 50            1230      ACT_required              100            20.0
# 34            1256      ACT_required               98            20.3
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 24  neither_required                3  ...            18.6  neither_required
# ...

# %% [markdown]
# Interestingly, in Washington DC recorded 100% participation and scored high for the remaining 2 years, despite having a mandatory requirement for either exam. However, Washington D.C does provide SAT for free to students so this is understandable. As expected the top performing states participation-wise from 2017 t0 2019 had "SAT-mandatory" policies (asides D.C.). Mississipi, Iowa, Wisconsin, Wyoming and North Dakota featured consistently in the bottom 5 in terms of participation rate from 2017 to 2019. Wisconsin, Wyoming and North Dakota are "ACT mandatory" states, while Mississipi and Iowa do not require either test.

# %%
#Which states have the highest participation rates for the 2017 ACT?
sat_act_df.sort_values(by=['act_p_rate_2017'], ascending= False).head(5)
# Out:
#         state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 0     Alabama                5           593            572            1165
# 17   Kentucky                4           631            616            1247
# 49  Wisconsin                3           642            649            1291
# 44       Utah                3           624            614            1238
# 42  Tennessee                5           623            604            1228
#
#    sat_2017_policy  act_p_rate_2017  act_total_2017 act_2017_policy  \
# 0     ACT_required              100            19.2    ACT_required
# 17    ACT_required              100            20.0    ACT_required
# 49    ACT_required              100            20.5    ACT_required
# 44    ACT_required              100            20.3    ACT_required
# 42      ACT or SAT              100            19.8      ACT or SAT
#
#     sat_p_rate_2018  ...  act_total_2018  act_2018_policy  sat_p_rate_2019  \
# ...

# %%
#Which states have the highest participation rates for the 2018 ACT?
sat_act_df.sort_values(by=['act_p_rate_2018'], ascending= False).head(5)
# Out:
#         state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 0     Alabama                5           593            572            1165
# 17   Kentucky                4           631            616            1247
# 49  Wisconsin                3           642            649            1291
# 44       Utah                3           624            614            1238
# 42  Tennessee                5           623            604            1228
#
#    sat_2017_policy  act_p_rate_2017  act_total_2017 act_2017_policy  \
# 0     ACT_required              100            19.2    ACT_required
# 17    ACT_required              100            20.0    ACT_required
# 49    ACT_required              100            20.5    ACT_required
# 44    ACT_required              100            20.3    ACT_required
# 42      ACT or SAT              100            19.8      ACT or SAT
#
#     sat_p_rate_2018  ...  act_total_2018  act_2018_policy  sat_p_rate_2019  \
# ...

# %%
#Which states have the highest participation rates for the 2019 ACT?
sat_act_df.sort_values(by=['act_p_rate_2019'], ascending= False).head(5)
# Out:
#         state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 0     Alabama                5           593            572            1165
# 17   Kentucky                4           631            616            1247
# 49  Wisconsin                3           642            649            1291
# 44       Utah                3           624            614            1238
# 42  Tennessee                5           623            604            1228
#
#    sat_2017_policy  act_p_rate_2017  act_total_2017 act_2017_policy  \
# 0     ACT_required              100            19.2    ACT_required
# 17    ACT_required              100            20.0    ACT_required
# 49    ACT_required              100            20.5    ACT_required
# 44    ACT_required              100            20.3    ACT_required
# 42      ACT or SAT              100            19.8      ACT or SAT
#
#     sat_p_rate_2018  ...  act_total_2018  act_2018_policy  sat_p_rate_2019  \
# ...

# %%
#Which states have the lowest participation rates for the 2017 ACT?
sat_act_df.sort_values(by=['act_p_rate_2017'], ascending= False).tail(5)
# Out:
#             state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 38   Pennsylvania               65           540            531
# 39   Rhode Island               71           539            524
# 7        Delaware              100           503            492
# 29  New Hampshire               96           532            520
# 19          Maine               95           513            499
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 38            1071  neither_required               23            23.7
# 39            1062      SAT_required               21            24.0
# 7              996      SAT_required               18            24.1
# 29            1052      SAT_required               18            25.5
# 19            1012      SAT_required                8            24.3
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 38  neither_required               70  ...            23.5  neither_required
# ...

# %%
#Which states have the lowest participation rates for the 2018 ACT?
sat_act_df.sort_values(by=['act_p_rate_2018'], ascending= False).tail(5)
# Out:
#             state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 38   Pennsylvania               65           540            531
# 7        Delaware              100           503            492
# 29  New Hampshire               96           532            520
# 39   Rhode Island               71           539            524
# 19          Maine               95           513            499
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 38            1071  neither_required               23            23.7
# 7              996      SAT_required               18            24.1
# 29            1052      SAT_required               18            25.5
# 39            1062      SAT_required               21            24.0
# 19            1012      SAT_required                8            24.3
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 38  neither_required               70  ...            23.5  neither_required
# ...

# %%
#Which states have the lowest participation rates for the 2019 ACT?
sat_act_df.sort_values(by=['act_p_rate_2019'], ascending= False).tail(5)
# Out:
#             state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 38   Pennsylvania               65           540            531
# 29  New Hampshire               96           532            520
# 7        Delaware              100           503            492
# 39   Rhode Island               71           539            524
# 19          Maine               95           513            499
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 38            1071  neither_required               23            23.7
# 29            1052      SAT_required               18            25.5
# 7              996      SAT_required               18            24.1
# 39            1062      SAT_required               21            24.0
# 19            1012      SAT_required                8            24.3
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 38  neither_required               70  ...            23.5  neither_required
# ...

# %% [markdown]
# Alabama, Kentucky, Wisconsin, Utah and Tennessee recorded 100% participation across the 3 years studied. All 5 are "ACT required" states asides Tennessee which requires either the ACT or SAT. Conversely,Pennsylvania, Rhode Island, Delaware, New Hampshire and Maine were least perfoming in terms of participation rate from 2017-2019. All 5 are "SAT required" states, asides Pennsylvania which requires neither test.

# %% [markdown]
# #### The following lines of code addrees the question: Which states have the highest and lowest mean total/composite scores for the 2017, 2018 and 2019 SAT?

# %%
sat_act_df.sort_values(by=['sat_total_2017'], ascending= False).head(5)
# Out:
#         state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 23  Minnesota                3           644            651            1295
# 49  Wisconsin                3           642            649            1291
# 15       Iowa                2           641            635            1275
# 25   Missouri                3           640            631            1271
# 16     Kansas                4           632            628            1260
#
#      sat_2017_policy  act_p_rate_2017  act_total_2017   act_2017_policy  \
# 23  neither_required              100            21.5  neither_required
# 49      ACT_required              100            20.5      ACT_required
# 15  neither_required               67            21.9  neither_required
# 25      ACT_required              100            20.4      ACT_required
# 16  neither_required               73            21.7  neither_required
#
# ...

# %%
sat_act_df.sort_values(by=['sat_total_2018'], ascending= False).head(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 23     Minnesota                3           644            651
# 49     Wisconsin                3           642            649
# 34  North Dakota                2           635            621
# 15          Iowa                2           641            635
# 16        Kansas                4           632            628
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 23            1295  neither_required              100            21.5
# 49            1291      ACT_required              100            20.5
# 34            1256      ACT_required               98            20.3
# 15            1275  neither_required               67            21.9
# 16            1260  neither_required               73            21.7
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 23  neither_required                4  ...            21.3  neither_required
# ...

# %%
sat_act_df.sort_values(by=['sat_total_2019'], ascending= False).head(5)
# Out:
#            state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 23     Minnesota                3           644            651
# 49     Wisconsin                3           642            649
# 41  South Dakota                3           612            603
# 34  North Dakota                2           635            621
# 27      Nebraska                3           629            625
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 23            1295  neither_required              100            21.5
# 49            1291      ACT_required              100            20.5
# 41            1216  neither_required               80            21.8
# 34            1256      ACT_required               98            20.3
# 27            1253      ACT_required               84            21.4
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 23  neither_required                4  ...            21.3  neither_required
# ...

# %%
sat_act_df.sort_values(by=['sat_total_2017'], ascending= False).tail(5)
# Out:
#                    state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 19                 Maine               95           513            499
# 12                 Idaho               93           513            493
# 22              Michigan              100           509            495
# 7               Delaware              100           503            492
# 8   District of Columbia              100           482            468
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 19            1012      SAT_required                8            24.3
# 12            1005        ACT or SAT               38            22.3
# 22            1005      SAT_required               29            24.1
# 7              996      SAT_required               18            24.1
# 8              950  neither_required               32            24.2
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df.sort_values(by=['sat_total_2018'], ascending= False).tail(5)
# Out:
#                    state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 11                Hawaii               55           544            541
# 12                 Idaho               93           513            493
# 48         West Virginia               14           558            528
# 7               Delaware              100           503            492
# 8   District of Columbia              100           482            468
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 11            1085      ACT_required               90            19.0
# 12            1005        ACT or SAT               38            22.3
# 48            1086      SAT_required               69            20.4
# 7              996      SAT_required               18            24.1
# 8              950  neither_required               32            24.2
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df.sort_values(by=['sat_total_2019'], ascending= False).tail(5)
# Out:
#                    state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 12                 Idaho               93           513            493
# 7               Delaware              100           503            492
# 8   District of Columbia              100           482            468
# 36              Oklahoma                7           530            517
# 48         West Virginia               14           558            528
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 12            1005        ACT or SAT               38            22.3
# 7              996      SAT_required               18            24.1
# 8              950  neither_required               32            24.2
# 36            1047  neither_required              100            19.4
# 48            1086      SAT_required               69            20.4
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %% [markdown]
# The states that scored the highest on the SATs from 2017 to 2017 either required neither exam, or were ACT "mandatory states. Interestingly, Minnesota and Wisconson were the top 2 states in all three years. The 5 states which scored the least on the SATs were more diverse in terms of state policy. Idaho, requires either exam, but featured in in the bottom 5 list from 2017-2019. Hawaii is a "ACT mandatory state" but featured in the bottom 5 list in 2018. Oklahoma requires neither exam, had a low SAT participation rate (22%) but featured in the bottom 5 list in 2019.

# %% [markdown]
# #### The following lines of code addrees the question: Which states have the highest and lowest mean total/composite scores for the 2017, 2018 and 2019 ACT?

# %%
sat_act_df.sort_values(by=['act_total_2017'], ascending= False).head(5)
# Out:
#                    state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 29         New Hampshire               96           532            520
# 21         Massachusetts               76           555            551
# 6            Connecticut              100           530            512
# 19                 Maine               95           513            499
# 8   District of Columbia              100           482            468
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 29            1052      SAT_required               18            25.5
# 21            1107  neither_required               29            25.4
# 6             1041      SAT_required               31            25.2
# 19            1012      SAT_required                8            24.3
# 8              950  neither_required               32            24.2
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df.sort_values(by=['act_total_2018'], ascending= False).head(5)
# Out:
#             state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 6     Connecticut              100           530            512
# 21  Massachusetts               76           555            551
# 29  New Hampshire               96           532            520
# 32       New York               67           528            523
# 22       Michigan              100           509            495
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 6             1041      SAT_required               31            25.2
# 21            1107  neither_required               29            25.4
# 29            1052      SAT_required               18            25.5
# 32            1052  neither_required               31            24.2
# 22            1005      SAT_required               29            24.1
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 6       SAT_required              100  ...            25.6      SAT_required
# ...

# %%
sat_act_df.sort_values(by=['act_total_2019'], ascending= False).head(5)
# Out:
#             state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 21  Massachusetts               76           555            551
# 6     Connecticut              100           530            512
# 29  New Hampshire               96           532            520
# 39   Rhode Island               71           539            524
# 32       New York               67           528            523
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 21            1107  neither_required               29            25.4
# 6             1041      SAT_required               31            25.2
# 29            1052      SAT_required               18            25.5
# 39            1062      SAT_required               21            24.0
# 32            1052  neither_required               31            24.2
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 21  neither_required               80  ...            25.5  neither_required
# ...

# %%
sat_act_df.sort_values(by=['act_total_2017'], ascending= False).tail(5)
# Out:
#              state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 33  North Carolina               49           546            535
# 11          Hawaii               55           544            541
# 40  South Carolina               50           543            521
# 24     Mississippi                2           634            607
# 28          Nevada               26           563            553
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 33            1081      ACT_required              100            19.1
# 11            1085      ACT_required               90            19.0
# 40            1064  neither_required              100            18.7
# 24            1242  neither_required              100            18.6
# 28            1116      ACT_required              100            17.8
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df.sort_values(by=['act_total_2018'], ascending= False).tail(5)
# Out:
#              state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 0          Alabama                5           593            572
# 11          Hawaii               55           544            541
# 24     Mississippi                2           634            607
# 40  South Carolina               50           543            521
# 28          Nevada               26           563            553
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 0             1165      ACT_required              100            19.2
# 11            1085      ACT_required               90            19.0
# 24            1242  neither_required              100            18.6
# 40            1064  neither_required              100            18.7
# 28            1116      ACT_required              100            17.8
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df.sort_values(by=['act_total_2019'], ascending= False).tail(5)
# Out:
#              state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 0          Alabama                5           593            572
# 40  South Carolina               50           543            521
# 18       Louisiana                4           611            586
# 24     Mississippi                2           634            607
# 28          Nevada               26           563            553
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 0             1165      ACT_required              100            19.2
# 40            1064  neither_required              100            18.7
# 18            1198      ACT_required              100            19.5
# 24            1242  neither_required              100            18.6
# 28            1116      ACT_required              100            17.8
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %% [markdown]
# The top 5 performing states on the ACTs either required neither exam or were SAT mandatory. Connecticut, New Hampshire and Massachussets were among the top 5 performing states on the ACTs for the three years studied. Conversely, the lowest scoring states on the ACTs either required neither of the two exams, or were "ACT mandatory" states. Mississipi and Nevada featured in the "bottom 5" list across the 3 years studied.

# %% [markdown]
# #### Do any states show >50% participation on both tests each year?
# Yes. Interestingly, Florida, Georgia and Hawaii had particpation rates of over 50% in both exams in 2017 and 2018. Florida's participation rate in both the SAT and ACT were much above the national average. While both Florida and Georgia do not require either of the tests, the ACT is mandatory in Hawaii.
#
# North Carolina and South Carolina recorded over 50 per cent participation rates in both the ACTs and SATs in 2018 and 2019. The ACT is mandatory in North Carolina, while in South Carolina, neither exam is mandatory.

# %%
sat_act_df[(sat_act_df["sat_p_rate_2017"]>50) & (sat_act_df["act_p_rate_2017"]>50)]
# Out:
#       state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 9   Florida               83           520            497            1017
# 10  Georgia               61           535            515            1050
# 11   Hawaii               55           544            541            1085
#
#      sat_2017_policy  act_p_rate_2017  act_total_2017   act_2017_policy  \
# 9   neither_required               73            19.8  neither_required
# 10  neither_required               55            21.4  neither_required
# 11      ACT_required               90            19.0      ACT_required
#
#     sat_p_rate_2018  ...  act_total_2018   act_2018_policy  sat_p_rate_2019  \
# 9                56  ...            19.9  neither_required              100
# 10               70  ...            21.4  neither_required               71
# 11               56  ...            18.9      ACT_required               54
#
#    sat_r&w_2019  sat_math_2019  sat_total_2019   sat_2019_policy  \
# ...

# %%
sat_act_df[(sat_act_df["sat_p_rate_2018"]>50) & (sat_act_df["act_p_rate_2018"]>50)]
# Out:
#              state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 9          Florida               83           520            497
# 10         Georgia               61           535            515
# 11          Hawaii               55           544            541
# 33  North Carolina               49           546            535
# 40  South Carolina               50           543            521
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 9             1017  neither_required               73            19.8
# 10            1050  neither_required               55            21.4
# 11            1085      ACT_required               90            19.0
# 33            1081      ACT_required              100            19.1
# 40            1064  neither_required              100            18.7
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# ...

# %%
sat_act_df[(sat_act_df["sat_p_rate_2019"]>50) & (sat_act_df["act_p_rate_2019"]>50)]
# Out:
#              state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  \
# 9          Florida               83           520            497
# 11          Hawaii               55           544            541
# 33  North Carolina               49           546            535
# 40  South Carolina               50           543            521
#
#     sat_total_2017   sat_2017_policy  act_p_rate_2017  act_total_2017  \
# 9             1017  neither_required               73            19.8
# 11            1085      ACT_required               90            19.0
# 33            1081      ACT_required              100            19.1
# 40            1064  neither_required              100            18.7
#
#      act_2017_policy  sat_p_rate_2018  ...  act_total_2018   act_2018_policy  \
# 9   neither_required               56  ...            19.9  neither_required
# 11      ACT_required               56  ...            18.9      ACT_required
# ...

# %%
sat_act_df[sat_act_df["state"]== "Florida"]
# Out:
#      state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 9  Florida               83           520            497            1017
#
#     sat_2017_policy  act_p_rate_2017  act_total_2017   act_2017_policy  \
# 9  neither_required               73            19.8  neither_required
#
#    sat_p_rate_2018  ...  act_total_2018   act_2018_policy  sat_p_rate_2019  \
# 9               56  ...            19.9  neither_required              100
#
#   sat_r&w_2019  sat_math_2019  sat_total_2019   sat_2019_policy  \
# 9          516            483             999  neither_required
#
#    act_p_rate_2019  act_total_2019   act_2019_policy
# 9               54            20.1  neither_required
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sat_act_df.head()
# Out:
#         state  sat_p_rate_2017  sat_r&w_2017  sat_math_2017  sat_total_2017  \
# 0     Alabama                5           593            572            1165
# 1      Alaska               38           547            533            1080
# 2     Arizona               30           563            553            1116
# 3    Arkansas                3           614            594            1208
# 4  California               53           531            524            1055
#
#     sat_2017_policy  act_p_rate_2017  act_total_2017   act_2017_policy  \
# 0      ACT_required              100            19.2      ACT_required
# 1  neither_required               65            19.8  neither_required
# 2  neither_required               62            19.7  neither_required
# 3  neither_required              100            19.4  neither_required
# 4  neither_required               31            22.8  neither_required
#
#    sat_p_rate_2018  ...  act_total_2018   act_2018_policy  sat_p_rate_2019  \
# ...

# %%
#function to create correlaton matrix of a subset of the data frame sat_act_df:

def correl_plot(df, c_title, figsize):
    # Examine correlations of the participation rates and scores
    fig = plt.figure(figsize=figsize)
    mask = np.triu(np.ones_like(df.corr()))
    ax = sns.heatmap(df.corr(), 
                     annot = True,
                     annot_kws = {"size" : 15},
                     mask=mask,
                     cmap = "rocket")
    ax.set_title(c_title, fontsize = 20)
    ax.tick_params(axis="x", rotation = 45, labelsize = 16)
    ax.tick_params(axis="y", rotation = 0, labelsize = 16)
    y_min, y_max = ax.get_ylim()
    x_min, x_max = ax.get_xlim()
    ax.set_ylim(top=y_max+1)
    ax.set_xlim(right=x_max-1)
    fig.set_tight_layout(True)

#credit: Douglas Strodtman, cited in Stephen Godfrey https://github.com/sgodfrey66

# %%
#Create correlation matrix which shows correlations across available data for ACT &SAT participation rates and scores. 
subset_sat_act = sat_act_df[["sat_p_rate_2017", "sat_p_rate_2018", "sat_p_rate_2019",
                             "sat_total_2017", "sat_total_2018", "sat_total_2019", 
                             "act_p_rate_2017","act_p_rate_2018","act_p_rate_2019",
                             "act_total_2017", "act_total_2018", "act_total_2019"]]

correl_plot(subset_sat_act,
           "Correlation Matrix of SAT and ACT Participation Rates and Total Scores (2017-2019)  ",
           (20,9))

plt.savefig("SAT_ACT_correl_matrix")

# %% [markdown]
# The heatmap above presents the different correlations between ACT and SAT participation rates and scores for the period 2017- 2019. The heat map takes on a lighter shade as positive correlations become stronger and darkens as negative correlations become stronger.
#
# As expected, strong negative correlations can be observed between participation rates in a given year and the corresponding total/composite scores in the year. This is in line with the expectation that as participation increases, average performance on the test declines due to the fact that wider participation connotes a more diverse pool of candidates and hence, a wider spread of scores. Likewise, a lower participation rate is expected to be associated with a higher score on average, as a low participation intrinsically selects for higher performing students.
#
# It can also be observed that participation rate on the ACT is positively and highly correlated with average performance on the SAT and vice versa. This is because higher particiation in one test, implies lower participation in the other- which suggests better scores on average.
#
# Also as expected, participation on the ACT and SAT show a strong negative correlation due to the reasons detailed above.
#
# Interestingly, participation rate on the 2017 ACT and SAT, respectively show a moderate positive correlation with the average scores of the alternative tests (SATs and ACTs) for the subsequent years (2018 and 2019).

# %%
pair_plot_2017= sns.pairplot(tests_2017)
pair_plot_2017.fig.suptitle("Pair Plot of 2017 SAT & ACT Participation Rates & Scores", y=1.08)
# Out:
# Text(0.5, 1.08, 'Pair Plot of 2017 SAT & ACT Participation Rates & Scores')

# %% [markdown]
# The Pairplot for 2017 presents the pairwise relationships that exist between ACT and SAT participation rates and average scores for 2017. The histograms in the diagonal show the respective distributions of the individual variables, while the scatter plots in the upper and lower triangles depict the various associations among the variables.
#
# Observation of the histograms in the diagonal show that none of the variables studied seem to follow a normal distribution. SAT participation rate for the year is skewed to left, while ACT participation rate is skewed to the right. Average SAT math scores for the year are also heavily skewed to the right. Interestingly, SAT math scores can be seen to show a strong positive correlation with SAT reading and writing scores.
#
# Overall, the correlating relationships largely conform with the patterns observed in the heat map above.

# %%
pair_plot_2018= sns.pairplot(tests_2018)
pair_plot_2018.fig.suptitle("Pair Plot of 2018 SAT & ACT Participation Rates & Scores", y=1.08)
# Out:
# Text(0.5, 1.08, 'Pair Plot of 2018 SAT & ACT Participation Rates & Scores')

# %% [markdown]
# The trends observed in the pairplot for 2018, are very similar with those observed in the preceding year.
# However, the average SAT math score for the year is slightly skewed to the left, compared with the strong right skew observed in the preceding year.

# %%
pair_plot_2019= sns.pairplot(tests_2019)
pair_plot_2019.fig.suptitle("Pair Plot of 2019 SAT & ACT Participation Rates & Scores", y=1.08)
# Out:
# Text(0.5, 1.08, 'Pair Plot of 2019 SAT & ACT Participation Rates & Scores')

# %% [markdown]
# The trends observed in the pairplot for 2019, are also very similar with those observed in the preceding years.
# As is the case with the 2018 plot, the average SAT math score for the year is slightly skewed to the left, compared with the strong right skew observed in the 2017 dataset.

# %%
plt.figure(figsize = (15,8))

sat_total_2017= sns.boxplot(x="sat_2017_policy", y="sat_total_2017", data= tests_2017)
sat_total_2017.set_xlabel("State Policy",fontsize=16)
sat_total_2017.set_ylabel("Average Total SAT Score", fontsize=16);
sat_total_2017.set_title("Box Plot Categorizing Average Total SAT Scores (2017) by State Policy", fontsize= 18);
plt.savefig("SAT 2017 Box plots")

# %% [markdown]
# The box plot above shows the average total SAT scores, categorized by state policy. "ACT Mandatory" states have the highest average total SATs, which can be explained by the low SAT participation rates in these states. States where either the ACT or SAT are mandatory performed slightly better than contexts where neither test is required. States where SAT is required perform least, due, likely to the high SAT participation rates in these states.
#
# Average total SAT scores in "SAT required' states appear to be the most balanced distribution, compared to the other categories which appear to be skewed.

# %%
plt.figure(figsize = (15,8))
act_total_2017= sns.boxplot(x="sat_2017_policy", y="act_total_2017", data= sat_act_df)
act_total_2017.set_xlabel("State Policy",fontsize=16)
act_total_2017.set_ylabel("Average Total ACT Score", fontsize=16);
act_total_2017.set_title("Box Plot Categorizing Average Total ACT Scores (2017) by State Policy", fontsize= 18);
plt.savefig("ACT 2017 box plot")

# %% [markdown]
# "ACT Mandatory" states performed the least in the ACTs on the basis of composite score in 2017. This can be explained by the high ACT participation rates in these states which have been associated with lower scores. Unsurprisingly, "SAT mandatory" state scored highest, with the median score skewed highly to the right. Average ACT scores in states which require neither test depicted a balanced distribution (indicative of a broader and more diverse dataset), while in states with require either ACT or SAT, the median score was skewed highly to the right.

# %%
plt.figure(figsize = (15,8))
sat_total_2018= sns.boxplot(x="sat_2018_policy", y="sat_total_2018", data= sat_act_df)
sat_total_2018.set_xlabel("State Policy",fontsize=16)
sat_total_2018.set_ylabel("Average Total SAT Score", fontsize=16);
sat_total_2018.set_title("Box Plot Categorizing Average Total SAT Scores (2018) by State Policy", fontsize= 18);
plt.savefig("SAT 2018 box plot")

# %% [markdown]
# The trend was similar in 2018, except we see a very low SAT performance relative to the preceding year. This can largely be explained by the increase in SAT participation which would have depressed average total score. Scores are also condensed in a much narrower range, a different observation than was the case in the preceding year.

# %%
plt.figure(figsize = (15,8))
act_total_2018= sns.boxplot(x="sat_2018_policy", y="act_total_2018", data= sat_act_df)
act_total_2018.set_xlabel("State Policy",fontsize=16)
act_total_2018.set_ylabel("Average Total ACT Score", fontsize=16);
act_total_2018.set_title("Box Plot Categorizing Average Total ACT Scores (2018) by State Policy", fontsize= 18);
plt.savefig("ACT 2018 box plot")

# %% [markdown]
# The trend of average total ACT scores were similar to that of the preceding year. We can obeserve that asides "SAT required" states, "test optional" states recorded the higest median scores of the 4 sub groups. This category of states also showed a balanced distribution in 2018.

# %%
plt.figure(figsize = (15,8))
sat_total_2019= sns.boxplot(x="sat_2017_policy", y="sat_total_2019", data= sat_act_df)
sat_total_2019.set_xlabel("State Policy",fontsize=16)
sat_total_2019.set_ylabel("Average Total SAT Score", fontsize=16);
sat_total_2019.set_title("Box Plot Categorizing Average Total SAT Scores (2019) by State Policy", fontsize= 18);
plt.savefig("SAT 2019 Box Plot")

# %% [markdown]
# The overall trend of average total SAT scores in 2019 conformed with the patterns observed in 2017 and 2018.

# %%
plt.figure(figsize = (15,8))
act_total_2019= sns.boxplot(x="sat_2017_policy", y="act_total_2019", data= sat_act_df)
act_total_2019.set_xlabel("State Policy",fontsize=16)
act_total_2019.set_ylabel("Average Total ACT Score", fontsize=16);
act_total_2019.set_title("Box Plot Categorizing Average Total ACT Scores (2019) by State Policy", fontsize= 18);
plt.savefig("ACT 2019 Box plot")

# %% [markdown]
# The overall trend of average total ACT scores in 2019 conformed with the patterns observed in 2017 and 2018.

# %%
plt.figure(figsize = (15,8))
sat_math_2017= sns.boxplot(x="sat_2017_policy", y="sat_math_2017", data= sat_act_df)
sat_math_2017.set_xlabel("State Policy",fontsize=16)
sat_math_2017.set_ylabel("Average SAT Math Score", fontsize=16);
sat_math_2017.set_title("Box Plot Categorizing Average SAT Math Scores (2017) by State Policy", fontsize= 18);
plt.savefig("SAT math 2017")

# %% [markdown]
# Average scores in the math section of the SATs by category followed the trend observed with the overall scores. However, it can be observed that across all 4 categories, math scores for 2017 are condensed within a tigher range and this differs from what is observed in the subsequent years.

# %%
plt.figure(figsize = (15,8))
sat_rw_2017= sns.boxplot(x="sat_2017_policy", y="sat_r&w_2017", data= sat_act_df)
sat_rw_2017.set_xlabel("State Policy",fontsize=16)
sat_rw_2017.set_ylabel("Average SAT Reading & Writing Score", fontsize=16);
sat_rw_2017.set_title("Box Plot Categorizing Average SAT Reading & Writing  Scores(2017) by State Policy", fontsize= 18);
plt.savefig("SAT RW 2017")

# %% [markdown]
# For the reading and writing section of the 2017 SAT, states which require either SAT or ACT recorded a higher median average score than states where neither exam is mandatory, which differs from trend observed with the average total scores.

# %%
plt.figure(figsize = (15,8))
sat_rw_2018= sns.boxplot(x="sat_2018_policy", y="sat_r&w_2018", data= sat_act_df)
sat_rw_2018.set_xlabel("State Policy",fontsize=16)
sat_rw_2018.set_ylabel("Average SAT Reading & Writing Score", fontsize=16);
sat_rw_2018.set_title("Box Plot Categorizing Average SAT Reading & Writing Scores (2018) by State Policy", fontsize= 18);
plt.savefig("SAT rw 2018")

# %% [markdown]
# The trend observed here is aligned with the trend observed in average SAT total scores.

# %%
plt.figure(figsize = (15,8))
sat_math_2018= sns.boxplot(x="sat_2017_policy", y="sat_math_2018", data= sat_act_df)
sat_math_2018.set_xlabel("State Policy",fontsize=16)
sat_math_2018.set_ylabel("Average SAT Math Score", fontsize=16);
sat_math_2018.set_title("Box Plot Categorizing Average SAT Math Scores (2018) by State Policy", fontsize= 18);
plt.savefig("SAT Math 2018")

# %% [markdown]
# States where either the ACT or the SAT are mandatory recorded slightly higher median average Math scores than "test optional" states. This differs from what was observed with the average total scores.

# %%
plt.figure(figsize = (15,8))
sat_rw_2019= sns.boxplot(x="sat_2017_policy", y="sat_r&w_2019", data= sat_act_df)
sat_rw_2019.set_xlabel("State Policy",fontsize=16)
sat_rw_2019.set_ylabel("Average SAT Reading & Writing Score", fontsize=16);
sat_rw_2019.set_title("Box Plot Categorizing Average SAT Reading & Writing Scores (2019) by State Policy", fontsize= 18);
plt.savefig("SAT rw 2019")

# %% [markdown]
# As was the case with SAT Math scores for the preceding year, states where either the ACT or the SAT are mandatory recorded slightly higher median average reading & writing scores than "test optional" states. This differs from what was observed with the average total scores.

# %%
plt.figure(figsize = (15,8))
sat_math_2019= sns.boxplot(x="sat_2017_policy", y="sat_math_2019", data= sat_act_df)
sat_math_2019.set_xlabel("State Policy",fontsize=16)
sat_math_2019.set_ylabel("Average SAT Math Score", fontsize=16);
sat_math_2019.set_title("Box Plot Categorizing Average SAT Math Scores (2019) by State Policy", fontsize= 18);
plt.savefig("SAT Math 2019")

# %% [markdown]
# The trend of average SAT math scores in 2019, mirrored the trend of reading & writing scores in the same year.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Conclusion
# This analysis sought to answer the question "Will making the SAT or ACT mandatory have any effect on the State of South Carolina's average test scores? The answer to this question is **Yes** and the *likely* nature of this relationship is negative. This is premised, primarily, on the observed negative association between participation rate and avarage tests scores, and the possitive association between participation rates and a "test mandatory" policy stance. Key findings from the analysis are listed below:
#
#  > 1. Average test scores of a test are lowest in states where that test is mandatory and highest in states where the alternative test is mandatory.
#
# > 2. States that do not require either of the tests generally outperform states that require students to take at least one of them.
#
# > 3. In some cases, states with an "either or" policy recorded higher median SAT sectional scores than "test optional" states.
#
# > 4. It is possible to record over 50% participation in both tests even when one of the tests is mandatory in the state. Surpisingly, none of the states which require either the SAT or the ACT met this criteria.
#
# > 5. Despite having a "test optional" policy stance and providing both exams for free to interested students, the state of South Carolina scored below the national average in both the ACT and SAT across the three years studied.
#
# > 6. A strong, positive correlation was observed between average scores on the SAT Math and Evidence-Based Reading and Writing Sections.
#
#  ### Recommendations
# > 1.  Findings of the analysis suggest that states concerned with raising average test scores are likely better off having a test optional policy stance. The state can therefore retain its current policy stance.
#
# > 2. There is need for deeper analysis into uncovering the reason for below average test scores in the State. The positive correlation observed between the two sections on the SAT suggest that efforts to increase average test scores need to be holistic, and not necessarily targeted to specific sections of the test.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
